# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## WebScraping data from Oficial Neighbourhoods from RIO

# %%
url_bairros = 'https://pt.wikipedia.org/wiki/Lista_de_bairros_da_cidade_do_Rio_de_Janeiro'

# %%
source = requests.get(url_bairros).text
soup = BeautifulSoup(source,'lxml')

# %%
# Find table from wiki
table = soup.find('table', class_='wikitable')
trs = table.find_all('tr')

# %%
# TABLE to LIST OF LISTS
bairros = []
for tr in trs:
    for td in tr.find_all('td'):
        row = []
        for a in td.find_all('a'):
            if a.text in ['Central','Sul','Oeste','Norte']:
                zona = a.text
            elif a.text in ['Bairro Imperial de São Cristóvão','Zona Sul','Barra da Tijuca e Baixada de Jacarepaguá','Grande Bangu','Zona Oeste','Grande Tijuca','Grande Méier','Ilha do Governador','Zona Norte']:
                sub = a.text
            elif a.text != '' and a.text[0] != '[' and a.text != 'Zona da Leopoldina':
                row = [zona,sub,a.text]
                bairros.append(row)

# %% [markdown]
# ### Transform data into Dataframe

# %%
# LIST OF LISTS TO DATAFRAME
df = pd.DataFrame(bairros)
df.shape
# Out:
# (160, 3)

# %%
# Rename columns Names
df = df.rename(columns={0:'ZONA',1:'SUB',2:'BAIRRO'})
df.head()
# Out:
#       ZONA                               SUB       BAIRRO
# 0  Central  Bairro Imperial de São Cristóvão      Benfica
# 1  Central  Bairro Imperial de São Cristóvão         Caju
# 2  Central  Bairro Imperial de São Cristóvão      Catumbi
# 3  Central  Bairro Imperial de São Cristóvão       Centro
# 4  Central  Bairro Imperial de São Cristóvão  Cidade Nova

# %%
# Error Centro Histórico e Zona Portuária
df.SUB.replace('Bairro Imperial de São Cristóvão','Centro Histórico e Zona Portuária', inplace = True)
imperial = {
    'ZONA' : 'Central',
    'SUB' : 'Centro Histórico e Zona Portuária',
    'BAIRRO' : 'São Cristóvão'
}
imperial = pd.DataFrame([imperial])
imperial = imperial.append(df , sort=True)

# %%
df = imperial
df = df.reset_index()
df = df.drop(['index'],axis=1)

# %%
df.head()
# Out:
#           BAIRRO                                SUB     ZONA
# 0  São Cristóvão  Centro Histórico e Zona Portuária  Central
# 1        Benfica  Centro Histórico e Zona Portuária  Central
# 2           Caju  Centro Histórico e Zona Portuária  Central
# 3        Catumbi  Centro Histórico e Zona Portuária  Central
# 4         Centro  Centro Histórico e Zona Portuária  Central

# %% [markdown]
# **UPPER CASE**

# %%
df['ZONA'] = df['ZONA'].str.upper()
df['SUB'] = df['SUB'].str.upper()
df['BAIRRO'] = df['BAIRRO'].str.upper()

# %%
df['BAIRRO'] = df['BAIRRO'].str.replace('Á','A')
df['BAIRRO'] = df['BAIRRO'].str.replace('É','E')
df['BAIRRO'] = df['BAIRRO'].str.replace('Í','I')
df['BAIRRO'] = df['BAIRRO'].str.replace('Ó','O')
df['BAIRRO'] = df['BAIRRO'].str.replace('Ú','U')
df['BAIRRO'] = df['BAIRRO'].str.replace('Â','A')
df['BAIRRO'] = df['BAIRRO'].str.replace('Ê','E')
df['BAIRRO'] = df['BAIRRO'].str.replace('Ã','A')
df['BAIRRO'] = df['BAIRRO'].str.replace('Ç','C')

# %%
df.head()
# Out:
#           BAIRRO                                SUB     ZONA
# 0  SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL
# 1        BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL
# 2           CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL
# 3        CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL
# 4         CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL

# %% [markdown]
# # Get Latitude and Longitude

# %%
import geocoder

# %%
lat = []
long = []

for i in df['BAIRRO']:
    lat_lng_coords = None
    print(i)

    while(lat_lng_coords is None):
        g = geocoder.arcgis('{} , RIO DE JANEIRO'.format(i))
        lat_lng_coords = g.latlng
        print(g)
        
    lat.append(lat_lng_coords[0])
    long.append(lat_lng_coords[1])
# Out:
# SAO CRISTOVAO
# <[OK] Arcgis - Geocode [São Cristóvão, Rio de Janeiro]>
# BENFICA
# <[OK] Arcgis - Geocode [Benfica, Rio de Janeiro]>
# CAJU
# <[OK] Arcgis - Geocode [Caju, Rio de Janeiro]>
# CATUMBI
# <[OK] Arcgis - Geocode [Catumbi, Rio de Janeiro]>
# CENTRO
# <[OK] Arcgis - Geocode [Centro, Bom Jesus do Itabapoana, Rio de Janeiro]>
# CIDADE NOVA
# <[OK] Arcgis - Geocode [Cidade Nova, Rio de Janeiro]>
# ESTACIO
# <[OK] Arcgis - Geocode [Estácio, Rio de Janeiro]>
# GAMBOA
# <[OK] Arcgis - Geocode [Gamboa, Rio de Janeiro]>
# LAPA
# <[OK] Arcgis - Geocode [Lapa, Rio de Janeiro]>
# MANGUEIRA
# <[OK] Arcgis - Geocode [Mangueira, Sapucaia, Rio de Janeiro]>
# PAQUETA
# <[OK] Arcgis - Geocode [Paquetá, Rio de Janeiro]>
# RIO COMPRIDO
# <[OK] Arcgis - Geocode [Rio Comprido, Rio de Janeiro]>
# SANTA TERESA
# <[OK] Arcgis - Geocode [Santa Teresa, Rio de Janeiro]>
# SANTO CRISTO
# <[OK] Arcgis - Geocode [Santo Cristo, Rio de Janeiro]>
# SAUDE
# <[OK] Arcgis - Geocode [Saúde, Rio de Janeiro]>
# VASCO DA GAMA
# <[OK] Arcgis - Geocode [Vasco da Gama, Rio de Janeiro]>
# BOTAFOGO
# <[OK] Arcgis - Geocode [Botafogo, Rio de Janeiro]>
# CATETE
# <[OK] Arcgis - Geocode [Catete, Rio de Janeiro]>
# COPACABANA
# <[OK] Arcgis - Geocode [Copacabana, Rio de Janeiro]>
# COSME VELHO
# <[OK] Arcgis - Geocode [Cosme Velho, Rio de Janeiro]>
# FLAMENGO
# <[OK] Arcgis - Geocode [Flamengo, Rio de Janeiro]>
# GAVEA
# <[OK] Arcgis - Geocode [Gávea, Rio de Janeiro]>
# GLORIA
# <[OK] Arcgis - Geocode [Glória, Rio de Janeiro]>
# HUMAITA
# <[OK] Arcgis - Geocode [Humaitá, Rio de Janeiro]>
# IPANEMA
# <[OK] Arcgis - Geocode [Ipanema, Rio de Janeiro]>
# JARDIM BOTANICO
# <[OK] Arcgis - Geocode [Jardim Botãnico, Rio de Janeiro]>
# LAGOA
# <[OK] Arcgis - Geocode [Lagoa, Rio de Janeiro]>
# LARANJEIRAS
# <[OK] Arcgis - Geocode [Laranjeiras, São Fidélis, Rio de Janeiro]>
# LEBLON
# <[OK] Arcgis - Geocode [Leblon, Rio de Janeiro]>
# LEME
# <[OK] Arcgis - Geocode [Leme, Rio de Janeiro]>
# SAO CONRADO
# <[OK] Arcgis - Geocode [São Conrado, Rio de Janeiro]>
# URCA
# <[OK] Arcgis - Geocode [Urca, Rio de Janeiro]>
# VIDIGAL
# <[OK] Arcgis - Geocode [Vidigal, Rio de Janeiro]>
# ANIL
# <[OK] Arcgis - Geocode [Anil, Rio de Janeiro]>
# BARRA DA TIJUCA
# <[OK] Arcgis - Geocode [Barra da Tijuca, Rio de Janeiro]>
# CAMORIM
# <[OK] Arcgis - Geocode [Camorim, Rio de Janeiro]>
# CIDADE DE DEUS
# <[OK] Arcgis - Geocode [Cidade de Deus, Rio de Janeiro]>
# CURICICA
# <[OK] Arcgis - Geocode [Curicica, Rio de Janeiro]>
# FREGUESIA DE JACAREPAGUA
# <[OK] Arcgis - Geocode [Freguesia (Jacarepaguá), Rio de Janeiro]>
# GARDENIA AZUL
# <[OK] Arcgis - Geocode [Gardênia Azul, Rio de Janeiro]>
# GRUMARI
# <[OK] Arcgis - Geocode [Grumari, Rio de Janeiro]>
# ITANHANGA
# <[OK] Arcgis - Geocode [Itanhangá, Rio de Janeiro]>
# JACAREPAGUA
# <[OK] Arcgis - Geocode [Jacarepaguá, Rio de Janeiro]>
# JOA
# <[OK] Arcgis - Geocode [Joá, Rio de Janeiro]>
# PRACA SECA
# <[OK] Arcgis - Geocode [Praça Seca, Rio de Janeiro]>
# PECHINCHA
# <[OK] Arcgis - Geocode [Pechincha, Rio de Janeiro]>
# RECREIO DOS BANDEIRANTES
# <[OK] Arcgis - Geocode [Recreio dos Bandeirantes, Rio de Janeiro]>
# TANQUE
# <[OK] Arcgis - Geocode [Tanque, Rio de Janeiro]>
# TAQUARA
# <[OK] Arcgis - Geocode [Taquara, Rio de Janeiro]>
# VARGEM GRANDE
# <[OK] Arcgis - Geocode [Vargem Grande, Rio de Janeiro]>
# VARGEM PEQUENA
# <[OK] Arcgis - Geocode [Vargem Pequena, Rio de Janeiro]>
# VILA VALQUEIRE
# <[OK] Arcgis - Geocode [Vila Valqueire, Rio de Janeiro]>
# JARDIM SULACAP
# <[OK] Arcgis - Geocode [Jardim Sulacap, Rio de Janeiro]>
# BANGU
# <[OK] Arcgis - Geocode [Bangu, Rio de Janeiro]>
# CAMPO DOS AFONSOS
# <[OK] Arcgis - Geocode [Campo dos Afonsos, Rio de Janeiro]>
# DEODORO
# <[OK] Arcgis - Geocode [Deodoro, Rio de Janeiro]>
# GERICINO
# <[OK] Arcgis - Geocode [Gericinó, Rio de Janeiro]>
# MAGALHAES BASTOS
# <[OK] Arcgis - Geocode [Magalhães Bastos, Rio de Janeiro]>
# PADRE MIGUEL
# <[OK] Arcgis - Geocode [Padre Miguel, Rio de Janeiro]>
# REALENGO
# <[OK] Arcgis - Geocode [Realengo, Rio de Janeiro]>
# SANTISSIMO
# <[OK] Arcgis - Geocode [Santíssimo, Rio de Janeiro]>
# SENADOR CAMARA
# <[OK] Arcgis - Geocode [Senador Camará, Rio de Janeiro]>
# VILA KENNEDY
# <[OK] Arcgis - Geocode [Vila Kennedy, Rio de Janeiro]>
# VILA MILITAR
# <[OK] Arcgis - Geocode [Vila Militar, Rio de Janeiro]>
# BARRA DE GUARATIBA
# <[OK] Arcgis - Geocode [Barra de Guaratiba, Rio de Janeiro]>
# CAMPO GRANDE
# <[OK] Arcgis - Geocode [Campo Grande, Rio de Janeiro]>
# COSMOS
# <[OK] Arcgis - Geocode [Cosmos, Rio de Janeiro]>
# GUARATIBA
# <[OK] Arcgis - Geocode [Guaratiba, Rio de Janeiro]>
# INHOAIBA
# <[OK] Arcgis - Geocode [Inhoaíba, Rio de Janeiro]>
# PACIENCIA
# <[OK] Arcgis - Geocode [Paciência, Rio de Janeiro]>
# PEDRA DE GUARATIBA
# <[OK] Arcgis - Geocode [Pedra de Guaratiba, Rio de Janeiro]>
# SANTA CRUZ
# <[OK] Arcgis - Geocode [Santa Cruz, Rio de Janeiro]>
# SENADOR VASCONCELOS
# <[OK] Arcgis - Geocode [Senador Vasconcelos, Rio de Janeiro]>
# SEPETIBA
# <[OK] Arcgis - Geocode [Sepetiba, Rio de Janeiro]>
# ALTO DA BOA VISTA
# <[OK] Arcgis - Geocode [Alto da Boa Vista, Rio de Janeiro]>
# ANDARAI
# <[OK] Arcgis - Geocode [Andaraí, Rio de Janeiro]>
# GRAJAU
# <[OK] Arcgis - Geocode [Grajaú, Rio de Janeiro]>
# MARACANA
# <[OK] Arcgis - Geocode [Maracanã, Rio de Janeiro]>
# PRACA DA BANDEIRA
# <[OK] Arcgis - Geocode [Práça da Bandeira, Rio de Janeiro]>
# TIJUCA
# <[OK] Arcgis - Geocode [Tijuca, Rio de Janeiro]>
# VILA ISABEL
# <[OK] Arcgis - Geocode [Vila Isabel, Rio de Janeiro]>
# ABOLICAO
# <[OK] Arcgis - Geocode [Abolição, Rio de Janeiro]>
# AGUA SANTA
# <[OK] Arcgis - Geocode [Água Santa, Rio de Janeiro]>
# CACHAMBI
# <[OK] Arcgis - Geocode [Cachambi, Rio de Janeiro]>
# DEL CASTILHO
# <[OK] Arcgis - Geocode [Del Castilho, Rio de Janeiro]>
# ENCANTADO
# <[OK] Arcgis - Geocode [Encantado, Rio de Janeiro]>
# ENGENHO DE DENTRO
# <[OK] Arcgis - Geocode [Engenho de Dentro, Rio de Janeiro]>
# ENGENHO NOVO
# <[OK] Arcgis - Geocode [Engenho Novo, Rio de Janeiro]>
# HIGIENOPOLIS
# <[OK] Arcgis - Geocode [Higienópolis, Rio de Janeiro]>
# JACARE
# <[OK] Arcgis - Geocode [Jacaré, Senador Camará, Rio de Janeiro]>
# JACAREZINHO
# <[OK] Arcgis - Geocode [Jacarezinho, Rio de Janeiro]>
# LINS DE VASCONCELOS
# <[OK] Arcgis - Geocode [Lins de Vasconcelos, Rio de Janeiro]>
# MANGUINHOS
# <[OK] Arcgis - Geocode [Manguinhos, Rio de Janeiro]>
# MARIA DA GRACA
# <[OK] Arcgis - Geocode [Maria da Graça, Rio de Janeiro]>
# MEIER
# <[OK] Arcgis - Geocode [Méier, Rio de Janeiro]>
# PIEDADE
# <[OK] Arcgis - Geocode [Piedade, Rio de Janeiro]>
# PILARES
# <[OK] Arcgis - Geocode [Pilares, Rio de Janeiro]>
# RIACHUELO
# <[OK] Arcgis - Geocode [Riachuelo, Rio de Janeiro]>
# ROCHA
# <[OK] Arcgis - Geocode [Rocha, Rio de Janeiro]>
# SAMPAIO
# <[OK] Arcgis - Geocode [Sampaio, Rio de Janeiro]>
# SAO FRANCISCO XAVIER
# <[OK] Arcgis - Geocode [São Francisco Xavier, Rio de Janeiro]>
# TODOS OS SANTOS
# <[OK] Arcgis - Geocode [Todos os Santos, Rio de Janeiro]>
# BONSUCESSO
# <[OK] Arcgis - Geocode [Bonsucesso, Rio de Janeiro]>
# BANCARIOS
# <[OK] Arcgis - Geocode [Bancários, Rio de Janeiro]>
# CACUIA
# <[OK] Arcgis - Geocode [Cacuia, Rio de Janeiro]>
# CIDADE UNIVERSITARIA
# <[OK] Arcgis - Geocode [Cidade Universitária, Rio de Janeiro]>
# COCOTA
# <[OK] Arcgis - Geocode [Cocotá, Rio de Janeiro]>
# FREGUESIA
# <[OK] Arcgis - Geocode [Freguesia, Rio de Janeiro]>
# GALEAO
# <[OK] Arcgis - Geocode [Galeão, Rio de Janeiro]>
# JARDIM CARIOCA
# <[OK] Arcgis - Geocode [Jardim Carioca, Rio de Janeiro]>
# JARDIM GUANABARA
# <[OK] Arcgis - Geocode [Jardim Guanabara, Rio de Janeiro]>
# MARE
# <[OK] Arcgis - Geocode [Maré, Rio de Janeiro]>
# MONERO
# <[OK] Arcgis - Geocode [Moneró, Rio de Janeiro]>
# OLARIA
# <[OK] Arcgis - Geocode [Olaria, Rio de Janeiro]>
# PITANGUEIRAS
# <[OK] Arcgis - Geocode [Pitangueiras, Rio de Janeiro]>
# PORTUGUESA
# <[OK] Arcgis - Geocode [Portuguesa, Rio de Janeiro]>
# PRAIA DA BANDEIRA
# <[OK] Arcgis - Geocode [Praia da Bandeira, Rio de Janeiro]>
# RAMOS
# <[OK] Arcgis - Geocode [Ramos, Rio de Janeiro]>
# RIBEIRA
# <[OK] Arcgis - Geocode [Ribeira, Rio de Janeiro]>
# TAUA
# <[OK] Arcgis - Geocode [Tauá, Rio de Janeiro]>
# ZUMBI
# <[OK] Arcgis - Geocode [Zumbi, Rio de Janeiro]>
# ACARI
# <[OK] Arcgis - Geocode [Acari, Rio de Janeiro]>
# ANCHIETA
# <[OK] Arcgis - Geocode [Anchieta, Rio de Janeiro]>
# BARROS FILHO
# <[OK] Arcgis - Geocode [Barros Filho, Rio de Janeiro]>
# BENTO RIBEIRO
# <[OK] Arcgis - Geocode [Bento Ribeiro, Rio de Janeiro]>
# BRAS DE PINA
# <[OK] Arcgis - Geocode [Brás de Pina, Rio de Janeiro]>
# CAMPINHO
# <[OK] Arcgis - Geocode [Campinho, Rio de Janeiro]>
# CAVALCANTI
# <[OK] Arcgis - Geocode [Cavalcanti, Rio de Janeiro]>
# CASCADURA
# <[OK] Arcgis - Geocode [Cascadura, Rio de Janeiro]>
# COELHO NETO
# <[OK] Arcgis - Geocode [Coelho Neto, Rio de Janeiro]>
# COLEGIO
# <[OK] Arcgis - Geocode [Colégio, Rio de Janeiro]>
# COMPLEXO DO ALEMAO
# <[OK] Arcgis - Geocode [Complexo do Alemão, Rio de Janeiro]>
# CORDOVIL
# <[OK] Arcgis - Geocode [Cordovil, Rio de Janeiro]>
# COSTA BARROS
# <[OK] Arcgis - Geocode [Costa Barros, Rio de Janeiro]>
# ENGENHEIRO LEAL
# <[OK] Arcgis - Geocode [Engenheiro Leal, Rio de Janeiro]>
# ENGENHO DA RAINHA
# <[OK] Arcgis - Geocode [Engenho da Rainha, Rio de Janeiro]>
# GUADALUPE
# <[OK] Arcgis - Geocode [Guadalupe, Rio de Janeiro]>
# HONORIO GURGEL
# <[OK] Arcgis - Geocode [Honório Gurgel, Rio de Janeiro]>
# INHAUMA
# <[OK] Arcgis - Geocode [Inhaúma, Rio de Janeiro]>
# IRAJA
# <[OK] Arcgis - Geocode [Irajá, Rio de Janeiro]>
# JARDIM AMERICA
# <[OK] Arcgis - Geocode [Jardim América, Rio de Janeiro]>
# MADUREIRA
# <[OK] Arcgis - Geocode [Madureira, Rio de Janeiro]>
# MARECHAL HERMES
# <[OK] Arcgis - Geocode [Marechal Hermes, Rio de Janeiro]>
# OSWALDO CRUZ
# <[OK] Arcgis - Geocode [Oswaldo Cruz, Rio de Janeiro]>
# PARADA DE LUCAS
# <[OK] Arcgis - Geocode [Parada de Lucas, Rio de Janeiro]>
# PARQUE ANCHIETA
# <[OK] Arcgis - Geocode [Parque Anchieta, Rio de Janeiro]>
# PARQUE COLUMBIA
# <[OK] Arcgis - Geocode [Parque Columbia, Rio de Janeiro]>
# PAVUNA
# <[OK] Arcgis - Geocode [Pavuna, Rio de Janeiro]>
# PENHA
# <[OK] Arcgis - Geocode [Penha, Rio de Janeiro]>
# PENHA CIRCULAR
# <[OK] Arcgis - Geocode [Penha Circular, Rio de Janeiro]>
# QUINTINO BOCAIUVA
# <[OK] Arcgis - Geocode [Quintino Bocaiúva, Rio de Janeiro]>
# RICARDO DE ALBUQUERQUE
# <[OK] Arcgis - Geocode [Ricardo de Albuquerque, Rio de Janeiro]>
# ROCHA MIRANDA
# <[OK] Arcgis - Geocode [Rocha Miranda, Rio de Janeiro]>
# TOMAS COELHO
# <[OK] Arcgis - Geocode [Tomas Coelho, Rio de Janeiro]>
# TURIACU
# <[OK] Arcgis - Geocode [Turiaçu, Rio de Janeiro]>
# VAZ LOBO
# <[OK] Arcgis - Geocode [Vaz Lobo, Rio de Janeiro]>
# VICENTE DE CARVALHO
# <[OK] Arcgis - Geocode [Vicente de Carvalho, Rio de Janeiro]>
# VIGARIO GERAL
# <[OK] Arcgis - Geocode [Vigário Geral, Rio de Janeiro]>
# VILA DA PENHA
# <[OK] Arcgis - Geocode [Vila da Penha, Rio de Janeiro]>
# VILA KOSMOS
# <[OK] Arcgis - Geocode [Vila Cosmos, Rio de Janeiro]>
# VISTA ALEGRE
# <[OK] Arcgis - Geocode [Vista Alegre, Rio de Janeiro]>

# %%
df['LAT'] = lat

# %%
df['LON'] = long

# %%
# DROP ERROR JACARE / LARANJEIRAS / CENTRO  / MANGUEIRA -22.905917, -43.235340
df = df.drop([89,27,4,9])

# %%
df.shape
# Out:
# (157, 5)

# %%
# ERRO BAIRRO JACARÉ
jac = {
    'ZONA' : ['NORTE','SUL','CENTRAL','CENTRAL'],
    'SUB' : ['GRANDE MÉIER','ZONA SUL','CENTRO HISTÓRICO E ZONA PORTUÁRIA','CENTRO HISTÓRICO E ZONA PORTUÁRIA'],
    'BAIRRO' : ['JACARE','LARANJEIRAS','CENTRO','MANGUEIRA'],
    'LAT' : [float(-22.891399),float(-22.934578),float(-22.908076),float(-22.905917)],
    'LON' : [float(-43.258224),float(-43.189662),float(-43.182324),float(-43.235340)]
}

jac = pd.DataFrame(jac, index=[89,27,4,9])
df = df.append(jac , ignore_index=False, sort=False)

# %%
df
# Out:
#             BAIRRO                                SUB     ZONA        LAT  \
# 0    SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.900200
# 1          BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.889890
# 2             CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.879920
# 3          CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.917590
# 5      CIDADE NOVA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.909860
# ..             ...                                ...      ...        ...
# 160   VISTA ALEGRE                         ZONA NORTE    NORTE -22.829950
# 89          JACARE                       GRANDE MÉIER    NORTE -22.891399
# 27     LARANJEIRAS                           ZONA SUL      SUL -22.934578
# 4           CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.908076
# 9        MANGUEIRA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.905917
#
#            LON
# 0   -43.230240
# 1   -43.245620
# 2   -43.222180
# 3   -43.197040
# 5   -43.200080
# ..         ...
# 160 -43.317950
# 89  -43.258224
# 27  -43.189662
# 4   -43.182324
# 9   -43.235340
#
# [161 rows x 5 columns]

# %%
df = df.sort_index()
df = df.reset_index()

# %%
df = df.drop(['index'],axis=1)

# %%
df.head()
# Out:
#           BAIRRO                                SUB     ZONA        LAT  \
# 0  SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.900200
# 1        BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.889890
# 2           CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.879920
# 3        CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.917590
# 4         CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.908076
#
#          LON
# 0 -43.230240
# 1 -43.245620
# 2 -43.222180
# 3 -43.197040
# 4 -43.182324

# %%
df.shape
# Out:
# (161, 5)

# %% [markdown]
# ## Creating Maps / Visualizations

# %%
import folium
import branca

# %%
g = geocoder.arcgis('RIO DE JANEIRO')
lat_lng_coords = g.latlng
latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto City are -22.91215999999997, -43.17500999999993.

# %% [markdown]
# # All Neighbourhoods map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(tiles='Stamen Terrain', location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, zona in zip(df['LAT'], df['LON'], df['BAIRRO'], df['ZONA']):
    label = '{}, {}'.format(bairro, zona)
    label = folium.Popup(label, parse_html=True)

    
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  
    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Regions map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(tiles='Stamen Terrain', location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, zona in zip(df['LAT'], df['LON'], df['BAIRRO'], df['ZONA']):
    label = '{}, {}'.format(bairro, zona)
    label = folium.Popup(label, parse_html=True)
    
    # Coloring Districs
    if zona == 'CENTRAL':
        c = 'blue'
    elif zona == 'NORTE':
        c = 'red'
    elif zona == 'SUL':
        c = 'orange'
    else:
        c = 'green'
        
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=c,
        fill=True,
        fill_color=c,
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  
    
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 10px; left: 10px; width: 190px; height: 45px; 
                            border:2px solid grey; z-index:9999; font-size:14px;
                            ">
                              &nbsp; CENTRAL > <i class="fa fa-circle" aria-hidden="true" style="color:blue"></i>
                              NORTE > <i class="fa fa-circle" aria-hidden="true" style="color:red"></i><br>
                              &nbsp; SUL > <i class="fa fa-circle" aria-hidden="true" style="color:orange"></i>
                              OESTE > <i class="fa fa-circle" aria-hidden="true" style="color:green"></i>

                </div>
                ''' 

map_rj.get_root().html.add_child(folium.Element(legend_html))
    
    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Subprefecture map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(tiles='Stamen Terrain' ,location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, zona in zip(df['LAT'], df['LON'], df['BAIRRO'], df['SUB']):
    label = '{}'.format(bairro)
    label = folium.Popup(label, parse_html=True)
    
    # Coloring Districs
    if zona == 'CENTRO HISTÓRICO E ZONA PORTUÁRIA':
        c = 'blue'
    elif zona == 'ZONA NORTE':
        c = 'yellow'
    elif zona == 'ILHA DO GOVERNADOR':
        c = 'grey'
    elif zona == 'GRANDE MÉIER':
        c = 'pink'
    elif zona == 'GRANDE TIJUCA':
        c = 'maroon'
    elif zona == 'ZONA OESTE':
        c = 'purple'
    elif zona == 'GRANDE BANGU':
        c = 'red'
    elif zona == 'BARRA DA TIJUCA E BAIXADA DE JACAREPAGUÁ':
        c = 'green'
    else:
        c = 'orange'
        
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=c,
        fill=True,
        fill_color=c,
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  
    
legend_html =   '''
                <div style="position: fixed; 
                            bottom: 10px; left: 10px; width: 260px; height: 60px; 
                            border:2px solid grey; z-index:9999; font-size:14px;
                            ">
                              &nbsp; Imperial > <i class="fa fa-circle" aria-hidden="true" style="color:blue"></i>
                              Zona N > <i class="fa fa-circle" aria-hidden="true" style="color:yellow"></i>
                              Ilha > <i class="fa fa-circle" aria-hidden="true" style="color:grey"></i><br>
                              &nbsp; G Meier > <i class="fa fa-circle" aria-hidden="true" style="color:pink"></i>
                              G Tijuc > <i class="fa fa-circle" aria-hidden="true" style="color:brown"></i>
                              Zona O > <i class="fa fa-circle" aria-hidden="true" style="color:purple"></i><br>
                              &nbsp; G Bangu > <i class="fa fa-circle" aria-hidden="true" style="color:red"></i>
                              Barra T > <i class="fa fa-circle" aria-hidden="true" style="color:green"></i>
                              Zona S > <i class="fa fa-circle" aria-hidden="true" style="color:orange"></i>

                </div>
                ''' 

map_rj.get_root().html.add_child(folium.Element(legend_html))
    
    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df.to_csv('bairros.csv')
