# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # WebScraping data from Neighbourhoods from RIO (Population Density)

# %%
url_bairros = 'https://pt.wikipedia.org/wiki/Lista_de_bairros_da_cidade_do_Rio_de_Janeiro'

# %%
source = requests.get(url_bairros).text
soup = BeautifulSoup(source,'lxml')

# %%
# Find table from wiki
table = soup.find('table', class_='wikitable')
trs = table.find_all('tr')

# %%
# Find All Links
hrefs = []
for tr in trs:
    for td in tr.find_all('td'):
        for a in td.find_all('a'):
            href = a.get('href')
            url = 'https://pt.wikipedia.org' + href
            if href[0] != '#' and not('(estado)' in href) and not('.JPG' in href) and not('.jpg' in href) :
                hrefs.append(url)

# %%
hrefs[0:5]
# Out:
# ['https://pt.wikipedia.org/wiki/S%C3%A3o_Crist%C3%B3v%C3%A3o_(bairro_do_Rio_de_Janeiro)',
#  'https://pt.wikipedia.org/wiki/Benfica_(bairro_do_Rio_de_Janeiro)',
#  'https://pt.wikipedia.org/wiki/Caju_(bairro_do_Rio_de_Janeiro)',
#  'https://pt.wikipedia.org/wiki/Catumbi',
#  'https://pt.wikipedia.org/wiki/Centro_(Rio_de_Janeiro)']

# %% [markdown]
# ### Remove Unwanted Links

# %%
hrefs.remove('https://pt.wikipedia.org/wiki/Zona_Sul_(Rio_de_Janeiro)')
hrefs.remove('https://pt.wikipedia.org/wiki/Zona_Sul_(Rio_de_Janeiro)')
hrefs.remove('https://pt.wikipedia.org/wiki/Zona_Oeste_(Rio_de_Janeiro)')
hrefs.remove('https://pt.wikipedia.org/wiki/Barra_e_Jacarepagu%C3%A1')
hrefs.remove('https://pt.wikipedia.org/wiki/Grande_Bangu')
hrefs.remove('https://pt.wikipedia.org/wiki/Ilha_do_Governador')
hrefs.remove('https://pt.wikipedia.org/wiki/Subprefeitura_da_Zona_Oeste_(Rio_de_Janeiro)')
hrefs.remove('https://pt.wikipedia.org/wiki/Zona_Norte_(Rio_de_Janeiro)')
hrefs.remove('https://pt.wikipedia.org/wiki/Grande_Tijuca')
hrefs.remove('https://pt.wikipedia.org/wiki/Grande_M%C3%A9ier')
hrefs.remove('https://pt.wikipedia.org/wiki/Zona_da_Leopoldina')
hrefs.remove('https://pt.wikipedia.org/wiki/Subprefeitura_da_Zona_Norte_da_cidade_do_Rio_de_Janeiro')

# %% [markdown]
# ## Extract Population and Area from Neighbourhoods Links

# %%
result = []

for x in hrefs:
    print(x)
    source = requests.get(x).text
    soup = BeautifulSoup(source,'lxml')
    table = soup.find('table', class_="infobox_v2")
    if table == None:
        table = soup.find('table', class_="infobox")
        st = "vertical-align:top; text-align:left;"
    else:
        st = "vertical-align: top; text-align: left;"

        
    hab = '0.0'
    area = '0,0'
    if table != None: 
        table.find_all('span', class_='fn')
        trs = table.find_all('tr')
        flag = True
        for tr in trs:
            for td in tr.find_all('td', style=st):
                information = td.text
                if flag and 'hab' in information:
                    hab = information[0:7]
                    flag = False
                elif flag and '2010' in information:
                    hab = information[0:7]
                    flag = False
                elif 'km' in information:
                    area = information[0:12]
                elif '2003' in  information:
                    area = information[0:10]
                
    row = [hab, area]
    print(row)
    result.append([hab,area])
# Out:
# https://pt.wikipedia.org/wiki/S%C3%A3o_Crist%C3%B3v%C3%A3o_(bairro_do_Rio_de_Janeiro)
# ['26,510 ', '410,56 ha ']
# https://pt.wikipedia.org/wiki/Benfica_(bairro_do_Rio_de_Janeiro)
# ['25,081 ', '173,64 ha ']
# https://pt.wikipedia.org/wiki/Caju_(bairro_do_Rio_de_Janeiro)
# ['20,477 ', '534,75 ha ']
# https://pt.wikipedia.org/wiki/Catumbi
# ['12 556 ', '53,95 ha (']
# https://pt.wikipedia.org/wiki/Centro_(Rio_de_Janeiro)
# ['41,142 ', '572,31 ha ']
# https://pt.wikipedia.org/wiki/Cidade_Nova_(Rio_de_Janeiro)
# ['5,466 (', '93,48 ha (']
# https://pt.wikipedia.org/wiki/Est%C3%A1cio_(bairro)
# ['17 189 ', '98,04 ha (']
# https://pt.wikipedia.org/wiki/Gamboa_(Rio_de_Janeiro)
# ['13 108 ', '111,29 ha ']
# https://pt.wikipedia.org/wiki/Lapa_(bairro_do_Rio_de_Janeiro)
# ['0.0', '40,00 ha (']
# https://pt.wikipedia.org/wiki/Mangueira_(Rio_de_Janeiro)
# ['17,835 ', '79,81 ha (']
# https://pt.wikipedia.org/wiki/Paquet%C3%A1_(bairro_do_Rio_de_Janeiro)
# ['3\xa0361 (', '170,57 ha ']
# ...

# %% [markdown]
# ## Results into DataFrame

# %%
resultdf = pd.DataFrame(result)

# %%
resultdf.rename(columns={0 : 'Hab', 1 : 'Area'}, inplace=True)

# %%
resultdf.head()
# Out:
#        Hab        Area
# 0  26,510   410,56 ha
# 1  25,081   173,64 ha
# 2  20,477   534,75 ha
# 3  12 556   53,95 ha (
# 4  41,142   572,31 ha

# %% [markdown]
# # CLEAN DATA

# %%
resultdf['Hab'] = resultdf['Hab'].str.strip(' (em')
resultdf['Hab'] = resultdf['Hab'].str.replace('\\xa0',' ')
resultdf['Hab'] = resultdf['Hab'].str.replace(',','')
resultdf['Hab'] = resultdf['Hab'].str.replace(' ','')
resultdf['Hab'] = resultdf['Hab'].str.replace('.','')

# %%
resultdf['Area'] = resultdf['Area'].str.replace('.','')
resultdf['Area'] = resultdf['Area'].str.replace(',','.')
resultdf['Area'] = resultdf['Area'].str.replace('ha','')
resultdf['Area'] = resultdf['Area'].str.replace('./','')
resultdf['Area'] = resultdf['Area'].str.replace('\\xa0','')
resultdf['Area'] = resultdf['Area'].str.replace('h','')
resultdf['Area'] = resultdf['Area'].str.replace('(','')
resultdf['Area'] = resultdf['Area'].str.replace('em','')
resultdf['Area'] = resultdf['Area'].str.replace('km²','')
resultdf['Area'] = resultdf['Area'].str.replace(' ','')
resultdf['Area'] = resultdf['Area'].str.replace('[','X')
resultdf['Area'] = resultdf['Area'].str.replace(']','X')
resultdf['Area'] = resultdf['Area'].str.replace('X1XX2X','')
resultdf['Area'] = resultdf['Area'].str.replace('ec','')

# %% [markdown]
# ## STRING TO FLOAT

# %%
resultdf['Area'] =  resultdf['Area'].apply(lambda x: float(x))
resultdf['Hab'] =  resultdf['Hab'].apply(lambda x: int(x))

# %% [markdown]
# # HA to KM^2

# %%
resultdf['Area'].head()
# Out:
# 0    410.56
# 1    173.64
# 2    534.75
# 3     53.95
# 4    572.31
# Name: Area, dtype: float64

# %%
resultdf['Area'] =  resultdf['Area'].apply(lambda x: x/100)

# %%
resultdf.head()
# Out:
#      Hab    Area
# 0  26510  4.1056
# 1  25081  1.7364
# 2  20477  5.3475
# 3  12556  0.5395
# 4  41142  5.7231

# %% [markdown]
# # Import Data with Bairros

# %%
bair = pd.read_csv('bairros.csv', index_col=0)

# %%
bair.head()
# Out:
#           BAIRRO                                SUB     ZONA        LAT  \
# 0  SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.900200
# 1        BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.889890
# 2           CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.879920
# 3        CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.917590
# 4         CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.908076
#
#          LON
# 0 -43.230240
# 1 -43.245620
# 2 -43.222180
# 3 -43.197040
# 4 -43.182324

# %% [markdown]
# # MERGE BAIRROS + DENSITY

# %%
merged = pd.concat([bair, resultdf], axis=1)

# %%
merged.shape
# Out:
# (161, 7)

# %%
merged.head()
# Out:
#           BAIRRO                                SUB     ZONA        LAT  \
# 0  SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.900200
# 1        BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.889890
# 2           CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.879920
# 3        CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.917590
# 4         CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.908076
#
#          LON    Hab    Area
# 0 -43.230240  26510  4.1056
# 1 -43.245620  25081  1.7364
# 2 -43.222180  20477  5.3475
# 3 -43.197040  12556  0.5395
# 4 -43.182324  41142  5.7231

# %% [markdown]
# # ADD MISSING DATA

# %%
merged.replace(0,np.nan , inplace=True)

# %%
merged.loc[8 , 'Hab'] = 4897 
merged.loc[15, 'Hab'] = 20126
merged.loc[15, 'Area'] = 1.0031
merged.loc[41, 'Hab'] = 38415
merged.loc[41, 'Area'] = 8.08
merged.loc[54, 'Hab'] = 1365
merged.loc[54, 'Area'] = 3.2523
merged.loc[62, 'Hab'] = 70000
merged.loc[62, 'Area'] = 7.2
merged.loc[69, 'Hab'] = 140527
merged.loc[21, 'Area'] = 2.5796
merged.loc[38, 'Area'] = 10.3961
merged.loc[56, 'Area'] = 7.3196
merged.loc[79, 'Area'] = 10.0656
merged.loc[150, 'Area'] = 4.3238
merged.loc[18, 'Area'] = 4.10
merged.loc[65, 'Hab'] = 328370
merged.loc[65, 'Area'] = 119
merged.loc[71, 'Area'] = 125
merged.loc[53, 'Area'] = 45.7

# %% [markdown]
# # Density

# %%
merged['Den'] = merged['Hab']/merged['Area']

# %% [markdown]
# # Visualizations

# %%
import folium
from branca.colormap import linear

# %%
latitude = -22.917421
longitude = -43.425574

# %% [markdown]
# **COLOR MAP Hab**

# %%
mini = merged['Hab'].min()
maxi = merged['Hab'].max()
z = (mini+maxi)/2
za = (z + mini)/2
zb = (z + maxi)/2
colormap = linear.Greens_09.scale(mini,maxi)
colormap = colormap.to_step(index=[500,37500,75000,150000,300000])
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %% [markdown]
# # Total Population Map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, hab in zip(merged['LAT'], merged['LON'], merged['BAIRRO'], merged['Hab']):
    label = '{}, {}'.format(bairro, hab)
    label = folium.Popup(label, parse_html=True)
        
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color= colormap(hab),
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  


colormap.caption = 'HAB NEIGHBOURHOOD RJ'
colormap.add_to(map_rj)

    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **COLOR MAP Area**

# %%
mini = merged['Area'].min()
maxi = merged['Area'].max()
z = (mini+maxi)/2
za = (z + mini)/2
zb = (z + maxi)/2
colormap = linear.Reds_09.scale(mini,maxi)
colormap = colormap.to_step(index=[mini,za,z,zb,maxi])
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#fff5f0ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %% [markdown]
# # Total Area Map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, area in zip(merged['LAT'], merged['LON'], merged['BAIRRO'], merged['Area']):
    label = '{}, {}'.format(bairro, area)
    label = folium.Popup(label, parse_html=True)
        
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color= colormap(area),
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  


colormap.caption = 'Area NEIGHBOURHOOD RJ'
colormap.add_to(map_rj)

    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **COLOR MAP Density**

# %%
mini = merged['Den'].min()
maxi = merged['Den'].max()
z = (mini+maxi)/2
za = (z + mini)/2
zb = (z + maxi)/2
colormap = linear.Greens_09.scale(mini,maxi)
colormap = colormap.to_step(index=[mini,za,z,zb,maxi])
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#f7fcf5ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" 
# ...

# %% [markdown]
# # Population Density Map

# %%
# create map of New York using latitude and longitude values
map_rj = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, bairro, den in zip(merged['LAT'], merged['LON'], merged['BAIRRO'], merged['Den']):
    label = '{}, {}'.format(bairro, den)
    label = folium.Popup(label, parse_html=True)
        
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color= colormap(den),
        fill_opacity=0.7,
        parse_html=False).add_to(map_rj)  


colormap.caption = 'Density NEIGHBOURHOOD RJ'
colormap.add_to(map_rj)

    
map_rj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Export Data

# %%
merged.head()
# Out:
#           BAIRRO                                SUB     ZONA        LAT  \
# 0  SAO CRISTOVAO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.900200
# 1        BENFICA  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.889890
# 2           CAJU  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.879920
# 3        CATUMBI  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.917590
# 4         CENTRO  CENTRO HISTÓRICO E ZONA PORTUÁRIA  CENTRAL -22.908076
#
#          LON      Hab    Area           Den
# 0 -43.230240  26510.0  4.1056   6457.034295
# 1 -43.245620  25081.0  1.7364  14444.252476
# 2 -43.222180  20477.0  5.3475   3829.266012
# 3 -43.197040  12556.0  0.5395  23273.401297
# 4 -43.182324  41142.0  5.7231   7188.761336

# %%
merged = merged.drop(['SUB','ZONA','LAT','LON'],axis=1)

# %%
merged.to_csv('density.csv')
